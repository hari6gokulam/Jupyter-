# %%
# %%writefile hari.txt     # to create a txt if already not thr or to overwrite
# I wandered lonely as a cloud
# I dont remember the second line
# Daffodils
# Out:
# UsageError: unrecognized arguments: # to create a txt if already not thr or to overwrite

# %%
hari=open('hari.txt')    # open txt file

# %%
hari.read()   #to read

# %%
hari.readlines()   # to read as csvs

# %%
hari.seek(0)   #seek the mouse pointer to zeroth position

# %%
pwd   # to locate
# Out:
# 'C:\\Users\\hari6\\Desktop'

# %%
hari.close()   #to close
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12020/3740173466.py in <module>
# ----> 1 hari.close()   #to close
#
# NameError: name 'hari' is not defined

# %%
hari.read()     #cannot read a file already closed

# %%
hari=open("C:\\Users\\hari6\\Desktop\\hari.txt")   # use pwd for location

# %%
hari.read()

# %%
#numPy
import numpy as np
mylist= [45,55,65]
print(np.array(mylist))   # to print that array square brachet shows single Dimensional array
mymatrix=[[1,2,3],[4,5,6],[7,8,9]]
print(np.array(mymatrix)) #print the matrix

print(np.arange(0,11,0.5)) # similar to range() here step size is 0.5

print(np.ones((5,5)))   # get ones as 5X5 matrix, similar for zeros
np.random.randn(4,5)  #generate a 4x5 matric with random elements

# %%
#Corey Schafer matlibplot

import matplotlib as mpl
from matplotlib import pyplot as plt
dev_x=[2,3,4,5,6,7,8,9,]
dev_y=[900,8,70,665,5,4,3886,200]  #defining y axis devs salary maybe
plt.plot(dev_x, dev_y)

py_dev_y=[3550, 3456, 78, 210,6,7000,8,9]  #random second plot for pydevs
plt.plot(dev_x, py_dev_y)

plt.xlabel('age')
plt.ylabel('age')
plt.title('median salary')
plt.legend(['devs','pydevs'])  # giving legends remember [] list
plt.show()   #dont know why

# %%
import matplotlib.pyplot as plt   
import numpy as np

x = np.linspace(0, 2 * np.pi, 200)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos, labels=people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12020/1585253054.py in <module>
#      16
#      17 ax.barh(y_pos, performance, xerr=error, align='center')
# ---> 18 ax.set_yticks(y_pos, labels=people)
#      19 ax.invert_yaxis()  # labels read top-to-bottom
#      20 ax.set_xlabel('Performance')
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# TypeError: set_ticks() got an unexpected keyword argument 'labels'

# %% [raw]
# import numpy as np
# import matplotlib.pyplot as plt
# from matplotlib.widgets import SpanSelector
#
# # Fixing random state for reproducibility
# np.random.seed(19680801)
#
# fig, (ax1, ax2) = plt.subplots(2, figsize=(8, 6))
#
# x = np.arange(0.0, 5.0, 0.01)
# y = np.sin(2 * np.pi * x) + 0.5 * np.random.randn(len(x))
#
# ax1.plot(x, y)
# ax1.set_ylim(-2, 2)
# ax1.set_title('Press left mouse button and drag '
#               'to select a region in the top graph')
#
# line2, = ax2.plot([], [])
#
#
# def onselect(xmin, xmax):
#     indmin, indmax = np.searchsorted(x, (xmin, xmax))
#     indmax = min(len(x) - 1, indmax)
#
#     region_x = x[indmin:indmax]
#     region_y = y[indmin:indmax]
#
#     if len(region_x) >= 2:
#         line2.set_data(region_x, region_y)
#         ax2.set_xlim(region_x[0], region_x[-1])
#         ax2.set_ylim(region_y.min(), region_y.max())
#         fig.canvas.draw_idle()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from plotly.offline import iplot
import plotly as py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16372/715435857.py in <module>
#       3 import matplotlib.pyplot as plt
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 5 from plotly.offline import iplot
#       6 import plotly as py
#
# ModuleNotFoundError: No module named 'plotly'

# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yfinance
# Out:
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.10-py3-none-any.whl size=8500 sha256=610b74afed90b8af6fe4f71d6cf32f141052a69f382238ae6d4adc66fab52650
#   Stored in directory: c:\users\hari6\appdata\local\pip\cache\wheels\f2\b5\2c\59ba95dcf854e542944c75fe3da584e4e3833b319735a0546c
# Successfully built multitasking
# ...

# %%
import streamlit as st
import pandas as pd

import yfinance as yf
import streamlit as st

st.write("""
# Simple Stock Price App

Shown are the stock closing price and volume of Google!

""")

# https://towardsdatascience.com/how-to-get-stock-data-using-python-c0de1df17e75
#define the ticker symbol
tickerSymbol = 'GOOGL'
#get data on this ticker
tickerData = yf.Ticker(tickerSymbol)
#get the historical prices for this ticker
tickerDf = tickerData.history(period='1d', start='2010-5-31', end='2020-5-31')
# Open	High	Low	Close	Volume	Dividends	Stock Splits

st.line_chart(tickerDf.Close)
st.line_chart(tickerDf.Volume)
# Out:
#   File "C:\Users\hari6\AppData\Local\Temp/ipykernel_16372/1119851071.py", line 25
#     streamlit run C:\Users\hari6\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
#               ^
# SyntaxError: invalid syntax
